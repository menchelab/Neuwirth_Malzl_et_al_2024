# %% [markdown]
# # Prepare resources

# %%
# download list of TFs
# !wget -O ../scenic_resource/hs_hgnc_curated_tfs.txt https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/hs_hgnc_curated_tfs.txt
# !wget -O ../scenic_resource/hs_hgnc_tfs.txt https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/hs_hgnc_tfs.txt
# !wget -O ../scenic_resource/lambert2018.txt https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/lambert2018.txt
# Out:
# --2024-06-07 09:36:13--  https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/hs_hgnc_curated_tfs.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8585 (8.4K) [text/plain]
# Saving to: ‘../scenic_resource/hs_hgnc_curated_tfs.txt’
#
# ../scenic_resource/ 100%[===================>]   8.38K  --.-KB/s    in 0s
#
# 2024-06-07 09:36:14 (133 MB/s) - ‘../scenic_resource/hs_hgnc_curated_tfs.txt’ saved [8585/8585]
#
# --2024-06-07 09:36:14--  https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/hs_hgnc_tfs.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11353 (11K) [text/plain]
# Saving to: ‘../scenic_resource/hs_hgnc_tfs.txt’
#
# ../scenic_resource/ 100%[===================>]  11.09K  --.-KB/s    in 0s
#
# 2024-06-07 09:36:14 (89.8 MB/s) - ‘../scenic_resource/hs_hgnc_tfs.txt’ saved [11353/11353]
#
# --2024-06-07 09:36:14--  https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/lambert2018.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10199 (10.0K) [text/plain]
# Saving to: ‘../scenic_resource/lambert2018.txt’
#
# ../scenic_resource/ 100%[===================>]   9.96K  --.-KB/s    in 0s
#
# 2024-06-07 09:36:14 (51.4 MB/s) - ‘../scenic_resource/lambert2018.txt’ saved [10199/10199]

# %%
def read_tf_file(filename):
    with open(filename, 'r') as tf_file:
        tfs = set(line.rstrip() for line in tf_file)
    
    return tfs


hgnc_tfs = read_tf_file('../scenic_resource/hs_hgnc_tfs.txt')
lambert_tfs = read_tf_file('../scenic_resource/lambert2018.txt')
hgnc_tfs_curated = read_tf_file('../scenic_resource/hs_hgnc_curated_tfs.txt')

(hgnc_tfs & lambert_tfs) == hgnc_tfs_curated
# Out:
# True

# %% [markdown]
# since they already provide the curated list we actually don't need to do all the things described [here](https://github.com/aertslab/pySCENIC/blob/master/notebooks/pySCENIC%20-%20List%20of%20Transcription%20Factors.ipynb). However, the [Nature protocol](https://www.nature.com/articles/s41596-020-0336-2) suggest using the full list found in `hgnc_tfs.txt` so we just follow this one and us it.

# %%
# download cistrarget databases
# !wget -O ../scenic_resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl https://resources.aertslab.org/cistarget/motif2tf/motifs-v9-nr.hgnc-m0.001-o0.0.tbl
# !wget -O ../scenic_resource/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather https://resources.aertslab.org/cistarget/databases/homo_sapiens/hg38/refseq_r80/mc9nr/gene_based/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather
# Out:
# --2024-06-07 09:56:35--  https://resources.aertslab.org/cistarget/motif2tf/motifs-v9-nr.hgnc-m0.001-o0.0.tbl
# Resolving resources.aertslab.org (resources.aertslab.org)... 134.58.50.9
# Connecting to resources.aertslab.org (resources.aertslab.org)|134.58.50.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103568514 (99M)
# Saving to: ‘../scenic_resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl.html’
#
# ../scenic_resource/ 100%[===================>]  98.77M  61.7MB/s    in 1.6s
#
# 2024-06-07 09:56:37 (61.7 MB/s) - ‘../scenic_resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl.html’ saved [103568514/103568514]
#
# --2024-06-07 09:56:37--  https://resources.aertslab.org/cistarget/databases/homo_sapiens/hg38/refseq_r80/mc9nr/gene_based/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather
# Resolving resources.aertslab.org (resources.aertslab.org)... 134.58.50.9
# Connecting to resources.aertslab.org (resources.aertslab.org)|134.58.50.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1248772066 (1.2G)
# Saving to: ‘../scenic_resource/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather.html’
#
# ../scenic_resource/ 100%[===================>]   1.16G  31.4MB/s    in 22s
#
# 2024-06-07 09:56:59 (55.1 MB/s) - ‘../scenic_resource/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather.html’ saved [1248772066/1248772066]

# %% [markdown]
# # Run SCENIC
# This follows the description of the full pipeline [here](https://github.com/aertslab/pySCENIC/blob/master/notebooks/pySCENIC%20-%20Full%20pipeline.ipynb). Beware that you may need to install pyscenic and aboreto from their git source. By the time of writing this there was one bug in either of their PyPI distributions that were fixed in the git sources but not propagated to PyPI due to them not bumping the package versions.

# %%
import anndata as ad

from arboreto.utils import load_tf_names
from arboreto.algo import grnboost2

from ctxcore.rnkdb import FeatherRankingDatabase as RankingDatabase
from pyscenic.utils import modules_from_adjacencies
from pyscenic.prune import prune2df, df2regulons
from pyscenic.aucell import aucell

# %%
adata = ad.read_h5ad('../data/tregs.tissue.scps.integrated.annotated.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 9773 × 20912
#     obs: 'sample_id', 'patient_id', 'status', 'tissue', 'cell_fraction', 'doublet', 'doublet_score', 'nFeature_RNA', 'nCount_RNA', 'percent_mt', 'percent_ribo', 'qc_pass', '_scvi_batch', '_scvi_labels', 'leiden_scvi_0.1', 'coarse_cell_types', 'leiden_scvi_0.4', 'dataset', 'sat1_status', 'clustering', 'sat1_status_majority_vote'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'leiden', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_scvi', 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
is_disease = adata.obs.status != 'normal'
is_sat1hi = adata.obs.sat1_status_majority_vote == 'SAT1_hi'
is_sat1lo = adata.obs.sat1_status_majority_vote == 'SAT1_lo'

data = {
    'all': adata,
    'all_disease': adata[is_disease],
    'sat1hi': adata[is_disease & is_sat1hi],
    'sat1lo': adata[is_disease & is_sat1lo]
}
data
# Out:
# {'all': AnnData object with n_obs × n_vars = 9773 × 20912
#      obs: 'sample_id', 'patient_id', 'status', 'tissue', 'cell_fraction', 'doublet', 'doublet_score', 'nFeature_RNA', 'nCount_RNA', 'percent_mt', 'percent_ribo', 'qc_pass', '_scvi_batch', '_scvi_labels', 'leiden_scvi_0.1', 'coarse_cell_types', 'leiden_scvi_0.4', 'dataset', 'sat1_status', 'clustering', 'sat1_status_majority_vote'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'leiden', 'log1p', 'neighbors', 'umap'
#      obsm: 'X_scvi', 'X_umap'
#      layers: 'counts'
#      obsp: 'connectivities', 'distances',
#  'all_disease': View of AnnData object with n_obs × n_vars = 4982 × 20912
#      obs: 'sample_id', 'patient_id', 'status', 'tissue', 'cell_fraction', 'doublet', 'doublet_score', 'nFeature_RNA', 'nCount_RNA', 'percent_mt', 'percent_ribo', 'qc_pass', '_scvi_batch', '_scvi_labels', 'leiden_scvi_0.1', 'coarse_cell_types', 'leiden_scvi_0.4', 'dataset', 'sat1_status', 'clustering', 'sat1_status_majority_vote'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'leiden', 'log1p', 'neighbors', 'umap'
#      obsm: 'X_scvi', 'X_umap'
#      layers: 'counts'
#      obsp: 'connectivities', 'distances',
#  'sat1hi': View of AnnData object with n_obs × n_vars = 2831 × 20912
#      obs: 'sample_id', 'patient_id', 'status', 'tissue', 'cell_fraction', 'doublet', 'doublet_score', 'nFeature_RNA', 'nCount_RNA', 'percent_mt', 'percent_ribo', 'qc_pass', '_scvi_batch', '_scvi_labels', 'leiden_scvi_0.1', 'coarse_cell_types', 'leiden_scvi_0.4', 'dataset', 'sat1_status', 'clustering', 'sat1_status_majority_vote'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'leiden', 'log1p', 'neighbors', 'umap'
#      obsm: 'X_scvi', 'X_umap'
#      layers: 'counts'
#      obsp: 'connectivities', 'distances',
#  'sat1lo': View of AnnData object with n_obs × n_vars = 2151 × 20912
#      obs: 'sample_id', 'patient_id', 'status', 'tissue', 'cell_fraction', 'doublet', 'doublet_score', 'nFeature_RNA', 'nCount_RNA', 'percent_mt', 'percent_ribo', 'qc_pass', '_scvi_batch', '_scvi_labels', 'leiden_scvi_0.1', 'coarse_cell_types', 'leiden_scvi_0.4', 'dataset', 'sat1_status', 'clustering', 'sat1_status_majority_vote'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'leiden', 'log1p', 'neighbors', 'umap'
#      obsm: 'X_scvi', 'X_umap'
#      layers: 'counts'
#      obsp: 'connectivities', 'distances'}

# %%
# load databases
with open('../scenic_resource/hs_hgnc_tfs.txt', 'r') as tf_file:
    tf_names = [line.rstrip() for line in tf_file]
    
cistarget_db = RankingDatabase(
    '../scenic_resource/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather',
    'hg38__refseq-r80__10kb_up_and_down_tss.mc9nr'
)
cistarget_db
# Out:
# FeatherRankingDatabase(name="hg38__refseq-r80__10kb_up_and_down_tss.mc9nr")

# %%
# this takes quite some time so get comfortable
from distributed import Client, LocalCluster
client = Client(
    LocalCluster(
        name = 'grn_call',
        n_workers = 8,
        threads_per_worker = 1
    )
)


grnboost_results = {}
for k, bdata in data.items():
    print(k)
    expr_data = bdata.to_df('counts')
    adjacencies = grnboost2(
        expression_data = expr_data,
        tf_names = tf_names,
        client_or_address = client,
        verbose = True
    )
    grnboost_results[k] = adjacencies
    
client.close()
del client
# Out:
# all
# preparing dask client
# parsing input
# creating dask graph
# 8 partitions
# computing dask graph
# /users/daniel.malzl/.conda/envs/scenic/lib/python3.12/site-packages/distributed/client.py:3164: UserWarning: Sending large graph of size 1.34 GiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# not shutting down client, client was created externally
# finished
# all_disease
# preparing dask client
# parsing input
# creating dask graph
# 8 partitions
# computing dask graph
# /users/daniel.malzl/.conda/envs/scenic/lib/python3.12/site-packages/distributed/client.py:3164: UserWarning: Sending large graph of size 663.12 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# not shutting down client, client was created externally
# finished
# sat1hi
# sat1lo

# %%
for k, result in grnboost_results.items():
    result.to_csv(
        f'../scenic_results/adj_{k}.tsv',
        sep = '\t'
    )

# %%
import pandas as pd


grnboost_results = {
    k: pd.read_csv(
        f'../scenic_results/adj_{k}.tsv', 
        sep = '\t', 
        index_col = 0
    )
    for k
    in ['sat1hi', 'sat1lo']
}

# %%
modules = {}
for k, bdata in data.items():
    inferred_modules = modules_from_adjacencies(
        grnboost_results[k],
        bdata.to_df('counts'),
        # according to pyscenic warning
        rho_mask_dropouts = True
    )
    # wrapping in list is needed because returned value is a generator
    # which is not going to work with the subsequent pruning
    modules[k] = list(inferred_modules)
# Out:
# 2024-06-07 17:19:21,373 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2024-06-07 17:19:21,805 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [True].
#
# 2024-06-07 17:20:49,886 - pyscenic.utils - INFO - Creating modules.
#
# 2024-06-07 17:21:41,090 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 2024-06-07 17:21:41,507 - pyscenic.utils - WARNING - Note on correlation calculation: the default behaviour for calculating the correlations has changed after pySCENIC verion 0.9.16. Previously, the default was to calculate the correlation between a TF and target gene using only cells with non-zero expression values (mask_dropouts=True). The current default is now to use all cells to match the behavior of the R verision of SCENIC. The original settings can be retained by setting 'rho_mask_dropouts=True' in the modules_from_adjacencies function, or '--mask_dropouts' from the CLI.
# 	Dropout masking is currently set to [True].
#
# 2024-06-07 17:22:14,974 - pyscenic.utils - INFO - Creating modules.

# %%
pruned_modules = {
    k: prune2df(
        [cistarget_db], 
        inferred_modules, 
        '../scenic_resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl',
        client_or_address = 'custom_multiprocessing',
        num_workers = 8
    )
    for k, inferred_modules
    in modules.items()
}
# Out:
# 2024-06-07 17:22:59,333 - pyscenic.prune - INFO - Using 8 workers.
#
# 2024-06-07 17:22:59,333 - pyscenic.prune - INFO - Using 8 workers.
#
# 2024-06-07 17:23:06,307 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): database loaded in memory.
#
# 2024-06-07 17:23:06,307 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): database loaded in memory.
#
# 2024-06-07 17:23:06,377 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): database loaded in memory.
#
# 2024-06-07 17:23:06,377 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): database loaded in memory.
#
# 2024-06-07 17:23:06,471 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): database loaded in memory.
#
# 2024-06-07 17:23:06,471 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): database loaded in memory.
#
# 2024-06-07 17:23:07,059 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): database loaded in memory.
#
# 2024-06-07 17:23:07,059 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): database loaded in memory.
#
# 2024-06-07 17:23:07,142 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): database loaded in memory.
#
# 2024-06-07 17:23:07,142 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): database loaded in memory.
#
# 2024-06-07 17:23:07,205 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): database loaded in memory.
#
# 2024-06-07 17:23:07,205 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): database loaded in memory.
#
# 2024-06-07 17:23:07,224 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): database loaded in memory.
#
# 2024-06-07 17:23:07,224 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): database loaded in memory.
#
# 2024-06-07 17:23:07,259 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): database loaded in memory.
#
# 2024-06-07 17:23:07,259 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): database loaded in memory.
#
# 2024-06-07 17:23:07,741 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): motif annotations loaded in memory.
#
# 2024-06-07 17:23:07,741 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): motif annotations loaded in memory.
#
# 2024-06-07 17:23:07,759 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): motif annotations loaded in memory.
#
# 2024-06-07 17:23:07,759 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): motif annotations loaded in memory.
#
# 2024-06-07 17:23:07,884 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): motif annotations loaded in memory.
#
# 2024-06-07 17:23:07,884 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,204 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,204 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,290 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,290 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,292 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,292 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,308 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,308 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,322 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): motif annotations loaded in memory.
#
# 2024-06-07 17:23:08,322 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): motif annotations loaded in memory.
#
# 2024-06-07 17:23:14,438 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF831 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:14,571 - pyscenic.transform - WARNING - Less than 80% of the genes in ZFP14 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:14,610 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SOCS4 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:14,624 - pyscenic.transform - WARNING - Less than 80% of the genes in ZFP90 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:16,568 - pyscenic.transform - WARNING - Less than 80% of the genes in ZHX2 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:16,625 - pyscenic.transform - WARNING - Less than 80% of the genes in ZKSCAN1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:17,134 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF821 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:17,185 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF830 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:17,232 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF831 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:17,328 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF880 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:18,036 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZFHX3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:18,270 - pyscenic.transform - WARNING - Less than 80% of the genes in AGMAT could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:18,425 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF100 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:19,541 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZSCAN5A could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:20,205 - pyscenic.transform - WARNING - Less than 80% of the genes in AGMAT could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:20,256 - pyscenic.transform - WARNING - Less than 80% of the genes in AHCTF1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:20,610 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF100 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:23:20,705 - pyscenic.transform - WARNING - Less than 80% of the genes in ZN
- pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): Done.
#
# 2024-06-07 17:27:34,195 - pyscenic.transform - WARNING - Less than 80% of the genes in TRMT1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:27:34,555 - pyscenic.transform - WARNING - Less than 80% of the genes in U2AF1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:27:37,053 - pyscenic.transform - WARNING - Less than 80% of the genes in UTP18 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:27:42,091 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for TRMT1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:27:42,474 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for U2AF1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:27:43,425 - pyscenic.transform - WARNING - Less than 80% of the genes in ZBTB25 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:27:46,969 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): All regulons derived.
#
# 2024-06-07 17:27:46,969 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): All regulons derived.
#
# 2024-06-07 17:27:47,121 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): Done.
#
# 2024-06-07 17:27:47,121 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): Done.
#
# 2024-06-07 17:28:01,721 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): All regulons derived.
#
# 2024-06-07 17:28:01,721 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): All regulons derived.
#
# 2024-06-07 17:28:01,938 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): Done.
#
# 2024-06-07 17:28:01,938 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): Done.
#
# 2024-06-07 17:28:40,803 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): All regulons derived.
#
# 2024-06-07 17:28:40,803 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): All regulons derived.
#
# 2024-06-07 17:28:41,350 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): Done.
#
# 2024-06-07 17:28:41,350 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): Done.
#
# 2024-06-07 17:28:42,332 - pyscenic.prune - INFO - Using 8 workers.
#
# 2024-06-07 17:28:42,332 - pyscenic.prune - INFO - Using 8 workers.
#
# 2024-06-07 17:28:47,621 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): database loaded in memory.
#
# 2024-06-07 17:28:47,621 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): database loaded in memory.
#
# 2024-06-07 17:28:47,629 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): database loaded in memory.
#
# 2024-06-07 17:28:47,629 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): database loaded in memory.
#
# 2024-06-07 17:28:47,923 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): database loaded in memory.
#
# 2024-06-07 17:28:47,923 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): database loaded in memory.
#
# 2024-06-07 17:28:47,997 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): database loaded in memory.
#
# 2024-06-07 17:28:47,997 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): database loaded in memory.
#
# 2024-06-07 17:28:48,282 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): database loaded in memory.
#
# 2024-06-07 17:28:48,282 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): database loaded in memory.
#
# 2024-06-07 17:28:48,343 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): database loaded in memory.
#
# 2024-06-07 17:28:48,343 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): database loaded in memory.
#
# 2024-06-07 17:28:48,378 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): database loaded in memory.
#
# 2024-06-07 17:28:48,378 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): database loaded in memory.
#
# 2024-06-07 17:28:48,593 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): database loaded in memory.
#
# 2024-06-07 17:28:48,593 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): database loaded in memory.
#
# 2024-06-07 17:28:49,195 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,195 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,258 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,258 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,380 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,380 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,388 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,388 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,416 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,416 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,450 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,450 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,495 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,495 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,671 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): motif annotations loaded in memory.
#
# 2024-06-07 17:28:49,671 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): motif annotations loaded in memory.
#
# 2024-06-07 17:28:57,126 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF831 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:28:58,281 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF831 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:28:58,925 - pyscenic.transform - WARNING - Less than 80% of the genes in AHCTF1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:09,199 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for TCF3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:13,057 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for TGIF1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:18,861 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for POLE3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:22,890 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF600 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:24,522 - pyscenic.transform - WARNING - Less than 80% of the genes in CNOT4 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:25,863 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF689 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:26,412 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF721 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:29,708 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF830 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:29,817 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF831 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:30,192 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF831 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:34,128 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ASH2L could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:36,592 - pyscenic.transform - WARNING - Less than 80% of the genes in CXXC1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:39,176 - pyscenic.transform - WARNING - Less than 80% of the genes in CNOT4 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:45,111 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for RPS6KA5 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:47,053 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF524 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:29:49,684 - pyscenic.transform - WARNING - Less than 80% of the genes in CRTC2 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:30:05,425 - pyscenic.transform - WARNING - Less than 80% of the genes in ETV3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:30:11,544 - pyscenic.transform - WARNING - Less than 80% of the genes in FANK1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:30:12,907 - pyscenic.transform - WARNING - Less than 80% of the genes in FOS could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:30:19,399 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for CXXC1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:30:23,468 - pyscenic.transform - WARNING - Less than 80% of the genes in GTF2A1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:30:30,844 - pyscenic.transform - WARNING - Less than 80% of the genes in HMGN3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:04,044 - pyscenic.transform - WARNING - Less than 80% of the genes in HDAC1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:07,302 - pyscenic.transform - WARNING - Less than 80% of the genes in TFAP4 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:07,332 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for GTF2A1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:16,086 - pyscenic.transform - WARNING - Less than 80% of the genes in MAX could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:39,952 - pyscenic.transform - WARNING - Less than 80% of the genes in PBX3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:42,521 - pyscenic.transform - WARNING - Less than 80% of the genes in KIF22 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:44,020 - pyscenic.transform - WARNING - Less than 80% of the genes in PML could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:49,007 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF789 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:49,482 - pyscenic.transform - WARNING - Less than 80% of the genes in PQBP1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:50,279 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): All regulons derived.
#
# 2024-06-07 17:31:50,279 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): All regulons derived.
#
# 2024-06-07 17:31:50,307 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): Done.
#
# 2024-06-07 17:31:50,307 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): Done.
#
# 2024-06-07 17:31:56,728 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for MAX could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:56,908 - pyscenic.transform - WARNING - Less than 80% of the genes in MAX could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:31:58,635 - pyscenic.transform - WARNING - Less than 80% of the genes in MBD1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:01,113 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for MAX could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:04,353 - pyscenic.transform - WARNING - Less than 80% of the genes in RPS6KA5 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:09,754 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for MTERF1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:15,826 - pyscenic.transform - WARNING - Less than 80% of the genes in SOCS4 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:18,167 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for JUND could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:21,572 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for POLE3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:23,659 - pyscenic.transform - WARNING - Less than 80% of the genes in PBX3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:25,678 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for PQBP1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:31,319 - pyscenic.transform - WARNING - Less than 80% of the genes in TGIF1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:39,462 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for MAX could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:39,805 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for RPS6KA5 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:44,233 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): All regulons derived.
#
# 2024-06-07 17:32:44,233 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): All regulons derived.
#
# 2024-06-07 17:32:44,388 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): Done.
#
# 2024-06-07 17:32:44,388 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): Done.
#
# 2024-06-07 17:32:45,545 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF614 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:48,595 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): All regulons derived.
#
# 2024-06-07 17:32:48,595 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): All regulons derived.
#
# 2024-06-07 17:32:48,652 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): Done.
#
# 2024-06-07 17:32:48,652 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): Done.
#
# 2024-06-07 17:32:50,631 - pyscenic.transform - WARNING - Less than 80% of the genes in RPS6KA5 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:55,249 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF789 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:32:59,761 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF524 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:33:00,102 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): All regulons derived.
#
# 2024-06-07 17:33:00,102 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): All regulons derived.
#
# 2024-06-07 17:33:00,364 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): Done.
#
# 2024-06-07 17:33:00,364 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): Done.
#
# 2024-06-07 17:33:02,416 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): All regulons derived.
#
# 2024-06-07 17:33:02,416 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): All regulons derived.
#
# 2024-06-07 17:33:02,580 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): Done.
#
# 2024-06-07 17:33:02,580 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): Done.
#
# 2024-06-07 17:33:21,374 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for SP4 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:33:28,166 - pyscenic.transform - WARNING - Less than 80% of the genes in TIA1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:33:30,245 - pyscenic.transform - WARNING - Less than 80% of the genes in TRIM21 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:33:33,902 - pyscenic.transform - WARNING - Less than 80% of the genes in UBE2K could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:33:37,832 - pyscenic.transform - WARNING - Less than 80% of the genes in XPA could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 17:33:41,659 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): All regulons derived.
#
# 2024-06-07 17:33:41,659 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): All regulons derived.
#
# 2024-06-07 17:33:41,885 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): Done.
#
# 2024-06-07 17:33:41,885 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): Done.
#
# 2024-06-07 17:33:55,409 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): All regulons derived.
#
# 2024-06-07 17:33:55,409 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): All regulons derived.
#
# 2024-06-07 17:33:55,635 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): Done.
#
# 2024-06-07 17:33:55,635 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): Done.
#
# 2024-06-07 17:34:00,387 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): All regulons derived.
#
# 2024-06-07 17:34:00,387 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): All regulons derived.
#
# 2024-06-07 17:34:00,921 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): Done.
#
# 2024-06-07 17:34:00,921 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): Done.

# %%
for k, pruned_modules_df in pruned_modules.items():
    pruned_modules_df.to_csv(
        f'../scenic_results/pruned_modules_{k}.tsv',
        sep = '\t'
    )

# %%
pruned_regulons = {
    k: df2regulons(
        pruned_modules_df
    )
    for k, pruned_modules_df
    in pruned_modules.items()
}
# Out:
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []

# %%
auc_mtxs = {}
for k, bdata in data.items():
    auc_mtx = aucell(
        bdata.to_df('counts'), 
        pruned_regulons[k], 
        num_workers = 8
    )
    auc_mtxs[k] = auc_mtx

# %%
for k, auc_mtx in auc_mtxs.items():
    auc_mtx.to_csv(
        f'../scenic_results/auc_mtx_{k}.tsv',
        sep = '\t'
    )

# %% [markdown]
# # Downstream analysis of SCENIC results
