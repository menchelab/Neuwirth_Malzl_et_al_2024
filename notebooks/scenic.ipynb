# %% [markdown]
# # Prepare resources

# %%
# download list of TFs
# !wget -O ../scenic_resource/hs_hgnc_curated_tfs.txt https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/hs_hgnc_curated_tfs.txt
# !wget -O ../scenic_resource/hs_hgnc_tfs.txt https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/hs_hgnc_tfs.txt
# !wget -O ../scenic_resource/lambert2018.txt https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/lambert2018.txt
# Out:
# --2024-06-07 09:36:13--  https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/hs_hgnc_curated_tfs.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8585 (8.4K) [text/plain]
# Saving to: ‘../scenic_resource/hs_hgnc_curated_tfs.txt’
#
# ../scenic_resource/ 100%[===================>]   8.38K  --.-KB/s    in 0s
#
# 2024-06-07 09:36:14 (133 MB/s) - ‘../scenic_resource/hs_hgnc_curated_tfs.txt’ saved [8585/8585]
#
# --2024-06-07 09:36:14--  https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/hs_hgnc_tfs.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11353 (11K) [text/plain]
# Saving to: ‘../scenic_resource/hs_hgnc_tfs.txt’
#
# ../scenic_resource/ 100%[===================>]  11.09K  --.-KB/s    in 0s
#
# 2024-06-07 09:36:14 (89.8 MB/s) - ‘../scenic_resource/hs_hgnc_tfs.txt’ saved [11353/11353]
#
# --2024-06-07 09:36:14--  https://raw.githubusercontent.com/aertslab/pySCENIC/master/resources/lambert2018.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10199 (10.0K) [text/plain]
# Saving to: ‘../scenic_resource/lambert2018.txt’
#
# ../scenic_resource/ 100%[===================>]   9.96K  --.-KB/s    in 0s
#
# 2024-06-07 09:36:14 (51.4 MB/s) - ‘../scenic_resource/lambert2018.txt’ saved [10199/10199]

# %%
def read_tf_file(filename):
    with open(filename, 'r') as tf_file:
        tfs = set(line.rstrip() for line in tf_file)
    
    return tfs


hgnc_tfs = read_tf_file('../scenic_resource/hs_hgnc_tfs.txt')
lambert_tfs = read_tf_file('../scenic_resource/lambert2018.txt')
hgnc_tfs_curated = read_tf_file('../scenic_resource/hs_hgnc_curated_tfs.txt')

(hgnc_tfs & lambert_tfs) == hgnc_tfs_curated
# Out:
# True

# %% [markdown]
# since they already provide the curated list we actually don't need to do all the things described [here](https://github.com/aertslab/pySCENIC/blob/master/notebooks/pySCENIC%20-%20List%20of%20Transcription%20Factors.ipynb). However, the [Nature protocol](https://www.nature.com/articles/s41596-020-0336-2) suggest using the full list found in `hgnc_tfs.txt` so we just follow this one and us it.

# %%
# download cistrarget databases
# !wget -O ../scenic_resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl https://resources.aertslab.org/cistarget/motif2tf/motifs-v9-nr.hgnc-m0.001-o0.0.tbl
# !wget -O ../scenic_resource/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather https://resources.aertslab.org/cistarget/databases/homo_sapiens/hg38/refseq_r80/mc9nr/gene_based/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather
# Out:
# --2024-06-07 09:56:35--  https://resources.aertslab.org/cistarget/motif2tf/motifs-v9-nr.hgnc-m0.001-o0.0.tbl
# Resolving resources.aertslab.org (resources.aertslab.org)... 134.58.50.9
# Connecting to resources.aertslab.org (resources.aertslab.org)|134.58.50.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 103568514 (99M)
# Saving to: ‘../scenic_resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl.html’
#
# ../scenic_resource/ 100%[===================>]  98.77M  61.7MB/s    in 1.6s
#
# 2024-06-07 09:56:37 (61.7 MB/s) - ‘../scenic_resource/motifs-v9-nr.hgnc-m0.001-o0.0.tbl.html’ saved [103568514/103568514]
#
# --2024-06-07 09:56:37--  https://resources.aertslab.org/cistarget/databases/homo_sapiens/hg38/refseq_r80/mc9nr/gene_based/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather
# Resolving resources.aertslab.org (resources.aertslab.org)... 134.58.50.9
# Connecting to resources.aertslab.org (resources.aertslab.org)|134.58.50.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1248772066 (1.2G)
# Saving to: ‘../scenic_resource/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather.html’
#
# ../scenic_resource/ 100%[===================>]   1.16G  31.4MB/s    in 22s
#
# 2024-06-07 09:56:59 (55.1 MB/s) - ‘../scenic_resource/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather.html’ saved [1248772066/1248772066]

# %% [markdown]
# # Run SCENIC
# This follows the description of the full pipeline [here](https://github.com/aertslab/pySCENIC/blob/master/notebooks/pySCENIC%20-%20Full%20pipeline.ipynb). Beware that you may need to install pyscenic and aboreto from their git source. By the time of writing this there was one bug in either of their PyPI distributions that were fixed in the git sources but not propagated to PyPI due to them not bumping the package versions.

# %%
import anndata as ad

from arboreto.utils import load_tf_names
from arboreto.algo import grnboost2

from ctxcore.rnkdb import FeatherRankingDatabase as RankingDatabase
from pyscenic.utils import modules_from_adjacencies
from pyscenic.prune import prune2df, df2regulons
from pyscenic.aucell import aucell

# %%
adata = ad.read_h5ad('../data/tregs.tissue.scps.integrated.annotated.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 9773 × 20912
#     obs: 'sample_id', 'patient_id', 'status', 'tissue', 'cell_fraction', 'doublet', 'doublet_score', 'nFeature_RNA', 'nCount_RNA', 'percent_mt', 'percent_ribo', 'qc_pass', '_scvi_batch', '_scvi_labels', 'leiden_scvi_0.1', 'coarse_cell_types', 'leiden_scvi_0.4', 'dataset', 'sat1_status', 'clustering', 'sat1_status_majority_vote'
#     uns: '_scvi_manager_uuid', '_scvi_uuid', 'leiden', 'log1p', 'neighbors', 'umap'
#     obsm: 'X_scvi', 'X_umap'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %%
is_disease = adata.obs.status != 'normal'
is_sat1hi = adata.obs.sat1_status_majority_vote == 'SAT1_hi'
is_sat1lo = adata.obs.sat1_status_majority_vote == 'SAT1_lo'

data = {
    'sat1hi': adata[is_disease & is_sat1hi],
    'sat1lo': adata[is_disease & is_sat1lo]
}
data
# Out:
# {'sat1hi': View of AnnData object with n_obs × n_vars = 2831 × 20912
#      obs: 'sample_id', 'patient_id', 'status', 'tissue', 'cell_fraction', 'doublet', 'doublet_score', 'nFeature_RNA', 'nCount_RNA', 'percent_mt', 'percent_ribo', 'qc_pass', '_scvi_batch', '_scvi_labels', 'leiden_scvi_0.1', 'coarse_cell_types', 'leiden_scvi_0.4', 'dataset', 'sat1_status', 'clustering', 'sat1_status_majority_vote'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'leiden', 'log1p', 'neighbors', 'umap'
#      obsm: 'X_scvi', 'X_umap'
#      layers: 'counts'
#      obsp: 'connectivities', 'distances',
#  'sat1lo': View of AnnData object with n_obs × n_vars = 2151 × 20912
#      obs: 'sample_id', 'patient_id', 'status', 'tissue', 'cell_fraction', 'doublet', 'doublet_score', 'nFeature_RNA', 'nCount_RNA', 'percent_mt', 'percent_ribo', 'qc_pass', '_scvi_batch', '_scvi_labels', 'leiden_scvi_0.1', 'coarse_cell_types', 'leiden_scvi_0.4', 'dataset', 'sat1_status', 'clustering', 'sat1_status_majority_vote'
#      uns: '_scvi_manager_uuid', '_scvi_uuid', 'leiden', 'log1p', 'neighbors', 'umap'
#      obsm: 'X_scvi', 'X_umap'
#      layers: 'counts'
#      obsp: 'connectivities', 'distances'}

# %%
# load databases
with open('../scenic_resource/hs_hgnc_tfs.txt', 'r') as tf_file:
    tf_names = [line.rstrip() for line in tf_file]
    
cistarget_db = RankingDatabase(
    '../scenic_resource/hg38__refseq-r80__10kb_up_and_down_tss.mc9nr.genes_vs_motifs.rankings.feather',
    'hg38__refseq-r80__10kb_up_and_down_tss.mc9nr'
)
cistarget_db
# Out:
# FeatherRankingDatabase(name="hg38__refseq-r80__10kb_up_and_down_tss.mc9nr")

# %%
# this takes quite some time so get comfortable
from distributed import Client, LocalCluster
client = Client(
    LocalCluster(
        name='grn_call',
        n_workers=8,
        threads_per_worker=1
    )
)


grnboost_results = {}
for k, bdata in data.items():
    print(k)
    expr_data = bdata.to_df('counts')
    adjacencies = grnboost2(
        expression_data = expr_data,
        tf_names = tf_names,
        client_or_address = client,
        verbose = True
    )
    grnboost_results[k] = adjacencies
    
client.close()
# Out:
# sat1hi
# preparing dask client
# parsing input
# creating dask graph
# 8 partitions
# computing dask graph
# /users/daniel.malzl/.conda/envs/scenic/lib/python3.12/site-packages/distributed/client.py:3164: UserWarning: Sending large graph of size 353.40 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# not shutting down client, client was created externally
# finished
# sat1lo
# preparing dask client
# parsing input
# creating dask graph
# 8 partitions
# computing dask graph
# /users/daniel.malzl/.conda/envs/scenic/lib/python3.12/site-packages/distributed/client.py:3164: UserWarning: Sending large graph of size 264.20 MiB.
# This may cause some slowdown.
# Consider scattering data ahead of time and using futures.
#   warnings.warn(
# not shutting down client, client was created externally
# finished

# %%
for k, result in grnboost_results.items():
    result.to_csv(
        f'../scenic_results/adj_{k}.tsv',
        sep = '\t'
    )

# %%
import pandas as pd


grnboost_results = {
    k: pd.read_csv(
        f'../scenic_results/adj_{k}.tsv', 
        sep = '\t', 
        index_col = 0
    )
    for k
    in ['sat1hi', 'sat1lo']
}

# %%
modules = {}
for k, bdata in data.items():
    inferred_modules = modules_from_adjacencies(
        grnboost_results[k],
        bdata.to_df('counts'),
        # according to pyscenic warning
        rho_mask_dropouts = True
    )
    # wrapping in list is needed because returned value is a generator
    # which is not going to work with the subsequent pruning
    modules[k] = list(inferred_modules)
# Out:
# 2024-06-07 14:17:30,367 - pyscenic.utils - INFO - Calculating Pearson correlations.
#
# 
- pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): Done.
#
# 2024-06-07 14:25:14,069 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): Done.
#
# 2024-06-07 14:25:19,285 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): All regulons derived.
#
# 2024-06-07 14:25:19,285 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): All regulons derived.
#
# 2024-06-07 14:25:19,412 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): Done.
#
# 2024-06-07 14:25:19,412 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): Done.
#
# 2024-06-07 14:25:19,711 - pyscenic.prune - INFO - Using 8 workers.
#
# 2024-06-07 14:25:19,711 - pyscenic.prune - INFO - Using 8 workers.
#
# 2024-06-07 14:25:24,784 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): database loaded in memory.
#
# 2024-06-07 14:25:24,784 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): database loaded in memory.
#
# 2024-06-07 14:25:25,098 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): database loaded in memory.
#
# 2024-06-07 14:25:25,098 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): database loaded in memory.
#
# 2024-06-07 14:25:25,276 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): database loaded in memory.
#
# 2024-06-07 14:25:25,276 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): database loaded in memory.
#
# 2024-06-07 14:25:25,366 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): database loaded in memory.
#
# 2024-06-07 14:25:25,366 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): database loaded in memory.
#
# 2024-06-07 14:25:25,397 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): database loaded in memory.
#
# 2024-06-07 14:25:25,397 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): database loaded in memory.
#
# 2024-06-07 14:25:25,525 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): database loaded in memory.
#
# 2024-06-07 14:25:25,525 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): database loaded in memory.
#
# 2024-06-07 14:25:25,559 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): database loaded in memory.
#
# 2024-06-07 14:25:25,559 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): database loaded in memory.
#
# 2024-06-07 14:25:25,584 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): database loaded in memory.
#
# 2024-06-07 14:25:25,584 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): database loaded in memory.
#
# 2024-06-07 14:25:26,021 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,021 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,332 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,332 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,422 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,422 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,451 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,451 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,532 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,532 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,572 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,572 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,605 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,605 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,629 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): motif annotations loaded in memory.
#
# 2024-06-07 14:25:26,629 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): motif annotations loaded in memory.
#
# 2024-06-07 14:25:46,455 - pyscenic.transform - WARNING - Less than 80% of the genes in BCL6 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:25:50,172 - pyscenic.transform - WARNING - Less than 80% of the genes in ZFP14 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:25:51,565 - pyscenic.transform - WARNING - Less than 80% of the genes in ZFP82 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:12,485 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF529 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:15,045 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF692 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:16,836 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF830 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:17,480 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF830 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:21,558 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF184 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:25,979 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ZNF234 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:41,771 - pyscenic.transform - WARNING - Less than 80% of the genes in FLI1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:44,547 - pyscenic.transform - WARNING - Less than 80% of the genes in RFXAP could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:51,860 - pyscenic.transform - WARNING - Less than 80% of the genes in GIT2 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:26:57,062 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for FLI1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:27:01,337 - pyscenic.transform - WARNING - Less than 80% of the genes in SETDB1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:27:07,694 - pyscenic.transform - WARNING - Less than 80% of the genes in FLI1 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:27:17,629 - pyscenic.transform - WARNING - Less than 80% of the genes in JUN could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:27:26,083 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for FOS could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:27:34,287 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for ING3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:27:46,248 - pyscenic.transform - WARNING - Less than 80% of the genes in ING3 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:28:03,194 - pyscenic.transform - WARNING - Less than 80% of the genes in Regulon for FOS could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:28:31,000 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): All regulons derived.
#
# 2024-06-07 14:28:31,000 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): All regulons derived.
#
# 2024-06-07 14:28:31,024 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): Done.
#
# 2024-06-07 14:28:31,024 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(4): Done.
#
# 2024-06-07 14:29:06,607 - pyscenic.transform - WARNING - Less than 80% of the genes in XPA could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:29:13,528 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF614 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:29:14,412 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): All regulons derived.
#
# 2024-06-07 14:29:14,412 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): All regulons derived.
#
# 2024-06-07 14:29:14,569 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): Done.
#
# 2024-06-07 14:29:14,569 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(2): Done.
#
# 2024-06-07 14:29:16,342 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF184 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:29:21,338 - pyscenic.transform - WARNING - Less than 80% of the genes in ZNF234 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:29:22,592 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): All regulons derived.
#
# 2024-06-07 14:29:22,592 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): All regulons derived.
#
# 2024-06-07 14:29:22,646 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): Done.
#
# 2024-06-07 14:29:22,646 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(3): Done.
#
# 2024-06-07 14:29:25,305 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): All regulons derived.
#
# 2024-06-07 14:29:25,305 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): All regulons derived.
#
# 2024-06-07 14:29:25,962 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): Done.
#
# 2024-06-07 14:29:25,962 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(8): Done.
#
# 2024-06-07 14:29:28,913 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): All regulons derived.
#
# 2024-06-07 14:29:28,913 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): All regulons derived.
#
# 2024-06-07 14:29:29,004 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): Done.
#
# 2024-06-07 14:29:29,004 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(5): Done.
#
# 2024-06-07 14:29:45,590 - pyscenic.transform - WARNING - Less than 80% of the genes in THAP11 could be mapped to hg38__refseq-r80__10kb_up_and_down_tss.mc9nr. Skipping this module.
#
# 2024-06-07 14:29:47,432 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): All regulons derived.
#
# 2024-06-07 14:29:47,432 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): All regulons derived.
#
# 2024-06-07 14:29:47,622 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): Done.
#
# 2024-06-07 14:29:47,622 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(1): Done.
#
# 2024-06-07 14:29:50,196 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): All regulons derived.
#
# 2024-06-07 14:29:50,196 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): All regulons derived.
#
# 2024-06-07 14:29:50,352 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): Done.
#
# 2024-06-07 14:29:50,352 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(6): Done.
#
# 2024-06-07 14:30:05,989 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): All regulons derived.
#
# 2024-06-07 14:30:05,989 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): All regulons derived.
#
# 2024-06-07 14:30:06,524 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): Done.
#
# 2024-06-07 14:30:06,524 - pyscenic.prune - INFO - Worker hg38__refseq-r80__10kb_up_and_down_tss.mc9nr(7): Done.

# %%
for k, pruned_modules_df in pruned_modules.items():
    pruned_modules_df.to_csv(
        f'../scenic_results/pruned_modules_{k}.tsv',
        sep = '\t'
    )

# %%
pruned_regulons = {
    k: df2regulons(
        pruned_modules_df
    )
    for k, pruned_modules_df
    in pruned_modules.items()
}
# Out:
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []
# Create regulons from a dataframe of enriched features.
# Additional columns saved: []

# %%
auc_mtxs = {}
for k, bdata in data.items():
    auc_mtx = aucell(
        bdata.to_df('counts'), 
        pruned_regulons[k], 
        num_workers = 8
    )
    auc_mtxs[k] = auc_mtx

# %%
for k, auc_mtx in auc_mtxs.items():
    auc_mtx.to_csv(
        f'../scenic_results/auc_mtx_{k}.tsv',
        sep = '\t'
    )

# %% [markdown]
# # Downstream analysis of SCENIC results
